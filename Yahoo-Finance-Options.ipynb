# %% [markdown]
# ## Yahoo-Finance-Options
#
# This notebook downloads option data from Yahoo Finance using the yahoo_fin package.
#
# We pick out a single case to compare the actual price on the market against the price predicted by Black-Scholes using volatility derived from returns on the underlying stock and a rate taken from the US Treasury.

# %%
#http://theautomatic.net/2019/04/17/how-to-get-options-data-with-python/
#https://algotrading101.com/learn/yahoo-finance-api-guide/
from yahoo_fin import options
import pandas as pd

# %%
ticker="nflx" # Netflix: change this to try out any other stocks available on Yahoo Finance

call_dates= options.get_expiration_dates(ticker)
call_dates
# Out:
# ['September 25, 2020',
#  'October 2, 2020',
#  'October 9, 2020',
#  'October 16, 2020',
#  'October 23, 2020',
#  'October 30, 2020',
#  'November 20, 2020',
#  'December 18, 2020',
#  'January 15, 2021',
#  'February 19, 2021',
#  'March 19, 2021',
#  'June 18, 2021',
#  'July 16, 2021',
#  'September 17, 2021',
#  'January 21, 2022',
#  'June 17, 2022']

# %%
import datetime
today = datetime.date.today()
#maturity = datetime.date(2020, 10, 23)    # Y M D
maturity = datetime.date(2021, 3, 19)    # Y M D
daycount = (maturity - today).days
print('maturity ',maturity,'    daycount ',daycount)


calls=options.get_calls("nflx", maturity)
calls["Volume"]=pd.to_numeric(calls["Volume"],errors='coerce') # coerce replaces - with NaN
calls[calls.Volume>10]
# Out:
# maturity  2021-03-19     daycount  180
#           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 13  NFLX210319C00425000  2020-09-11 12:48PM EDT   425.0       94.95  84.00
# 16  NFLX210319C00440000   2020-09-11 1:00PM EDT   440.0       86.35  75.80
# 17  NFLX210319C00445000   2020-09-11 1:00PM EDT   445.0       83.35  72.95
# 19  NFLX210319C00455000   2020-09-11 1:00PM EDT   455.0       78.30  67.35
# 20  NFLX210319C00460000   2020-09-18 3:46PM EDT   460.0       64.80  65.25
# 26  NFLX210319C00490000   2020-09-17 1:25PM EDT   490.0       52.80  51.95
# 37  NFLX210319C00545000  2020-09-16 12:29PM EDT   545.0       44.90  33.15
# 42  NFLX210319C00570000  2020-09-15 12:28PM EDT   570.0       39.00  26.95
# 43  NFLX210319C00575000  2020-09-17 11:41AM EDT   575.0       29.00  25.75
# 48  NFLX210319C00600000  2020-09-18 12:55PM EDT   600.0       20.90  20.90
# 55  NFLX210319C00680000   2020-09-08 1:18PM EDT   680.0       15.30   9.90
# 59  NFLX210319C00760000  2020-09-18 11:13AM EDT   760.0        6.20   4.40
# 60  NFLX210319C00780000  2020-09-09 11:28AM EDT   780.0       10.90   3.35
# 61  NFLX210319C00800000   2020-09-18 3:29PM EDT   800.0        4.65   2.71
# 62  NFLX210319C00820000  2020-09-18 12:29PM EDT   820.0        4.05   2.08
#
#       Ask  Change % Change  Volume  Open Interest Implied Volatility
# 13  87.45    0.00        -    15.0             16             49.93%
# 16  79.85    0.00        -    20.0             25             50.15%
# 17  77.30    0.00        -    15.0             15             50.10%
# 19  71.25    0.00        -    16.0             17             49.11%
# 20  69.55   -2.53   -3.76%    11.0             14             49.58%
# 26  54.95    0.00        -    25.0             60             48.04%
# 37  36.95    0.00        -    27.0             29             47.99%
# 42  30.80    0.00        -    70.0             76             48.08%
# 43  29.50    0.00        -    11.0             38             47.94%
# 48  24.80   -1.60   -7.11%    17.0             50             48.28%
# 55  13.00    0.00        -    14.0             35             47.80%
# 59   8.00   -0.85  -12.06%    24.0             68             49.63%
# 60   7.65    0.00        -    12.0             12             50.92%
# 61   6.65   -0.50   -9.71%    34.0             29             50.98%
# 62   5.90   -0.35   -7.95%    34.0             59             51.27%

# %%
mystrike=570
mycall=calls[calls.Strike == mystrike]
mycall
# Out:
#           Contract Name         Last Trade Date  Strike  Last Price    Bid  \
# 42  NFLX210319C00570000  2020-09-15 12:28PM EDT   570.0        39.0  26.95
#
#      Ask  Change % Change  Volume  Open Interest Implied Volatility
# 42  30.8     0.0        -    70.0             76             48.08%

# %%
myprice=float(0.5*(mycall["Bid"]+mycall["Ask"]))
print("Maturity in",daycount,"days", "Strike", mystrike, "Price",myprice)
# Out:
# Maturity in 180 days Strike 570 Price 28.875
